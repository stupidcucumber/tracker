# %%
from pathlib import Path
from src.data.dataset import DatasetGot10k

dataset = DatasetGot10k(
    root_dir=Path("dataset"),
    subset="val"
)

dataset[0]
# Out:
# (tensor([[[-1.1075, -1.1075, -1.1075,  ..., -1.1760, -1.1760, -1.2103],
#           [-1.1075, -1.1075, -1.1075,  ..., -1.1932, -1.1760, -1.1932],
#           [-1.1075, -1.1075, -1.0904,  ..., -1.2274, -1.1760, -1.1418],
#           ...,
#           [ 2.0263,  2.0263,  1.9920,  ...,  1.7865,  1.7865,  1.7694],
#           [ 1.8722,  1.8722,  1.8379,  ...,  1.7694,  1.7694,  1.7694],
#           [ 1.6495,  1.6495,  1.6153,  ...,  1.7180,  1.7180,  1.7523]],
#
#          [[-1.0728, -1.0728, -1.0728,  ..., -1.1253, -1.1253, -1.1604],
#           [-1.0728, -1.0728, -1.0728,  ..., -1.1253, -1.1253, -1.1253],
#           [-1.0728, -1.0728, -1.0553,  ..., -1.1253, -1.0728, -1.0378],
#           ...,
#           [ 2.1660,  2.1660,  2.1310,  ...,  1.9384,  1.9384,  1.9034],
#           [ 2.0084,  2.0084,  1.9734,  ...,  1.9034,  1.9034,  1.9034],
#           [ 1.7808,  1.7808,  1.7458,  ...,  1.8508,  1.8508,  1.8859]],
#
# ...
